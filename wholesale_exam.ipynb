# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Q04_Wholesale+customers+data.csv")

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %% [markdown]
# # 1.EDA

# %%
data.shape
# Out:
# (440, 8)

# %%
data.isnull().any()
# Out:
# Channel             False
# Region              False
# Fresh               False
# Milk                False
# Grocery             False
# Frozen              False
# Detergents_Paper    False
# Delicassen          False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
# Channel             440 non-null int64
# Region              440 non-null int64
# Fresh               440 non-null int64
# Milk                440 non-null int64
# Grocery             440 non-null int64
# Frozen              440 non-null int64
# Detergents_Paper    440 non-null int64
# Delicassen          440 non-null int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
data.describe().T
# Out:
#                   count          mean           std   min      25%     50%  \
# Channel           440.0      1.322727      0.468052   1.0     1.00     1.0
# Region            440.0      2.543182      0.774272   1.0     2.00     3.0
# Fresh             440.0  12000.297727  12647.328865   3.0  3127.75  8504.0
# Milk              440.0   5796.265909   7380.377175  55.0  1533.00  3627.0
# Grocery           440.0   7951.277273   9503.162829   3.0  2153.00  4755.5
# Frozen            440.0   3071.931818   4854.673333  25.0   742.25  1526.0
# Detergents_Paper  440.0   2881.493182   4767.854448   3.0   256.75   816.5
# Delicassen        440.0   1524.870455   2820.105937   3.0   408.25   965.5
#
#                        75%       max
# Channel               2.00       2.0
# Region                3.00       3.0
# Fresh             16933.75  112151.0
# Milk               7190.25   73498.0
# Grocery           10655.75   92780.0
# Frozen             3554.25   60869.0
# ...

# %%
data.corr()
# Out:
#                    Channel    Region     Fresh      Milk   Grocery    Frozen  \
# Channel           1.000000  0.062028 -0.169172  0.460720  0.608792 -0.202046
# Region            0.062028  1.000000  0.055287  0.032288  0.007696 -0.021044
# Fresh            -0.169172  0.055287  1.000000  0.100510 -0.011854  0.345881
# Milk              0.460720  0.032288  0.100510  1.000000  0.728335  0.123994
# Grocery           0.608792  0.007696 -0.011854  0.728335  1.000000 -0.040193
# Frozen           -0.202046 -0.021044  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper  0.636026 -0.001483 -0.101953  0.661816  0.924641 -0.131525
# Delicassen        0.056011  0.045212  0.244690  0.406368  0.205497  0.390947
#
#                   Detergents_Paper  Delicassen
# Channel                   0.636026    0.056011
# Region                   -0.001483    0.045212
# Fresh                    -0.101953    0.244690
# Milk                      0.661816    0.406368
# ...

# %%
corr = data.corr()
sns.heatmap(corr)

# %%
# Create the default pairplot
sns.pairplot(data)

# %% [markdown]
# # region wise data

# %%
plt.subplot(3, 1, 1)
plt.bar(data.Region , data.Milk,color='g')
plt.xlabel('Region')
plt.ylabel('Milk')
plt.title('region wise milk')
plt.show()
plt.subplot(3, 1, 2)
plt.bar(data.Region , data.Fresh,color='g')
plt.xlabel('Region')
plt.ylabel('Fresh')
plt.title('region wise freshness')
plt.show()
plt.subplot(3, 1, 3)
plt.bar(data.Region , data.Grocery,color='g')
plt.xlabel('Region')
plt.ylabel('Grocery')
plt.title('region wise grocery')
plt.show()

# %%
plt.subplot(3, 1, 1)
plt.bar(data.Region , data.Frozen,color='g')
plt.xlabel('Region')
plt.ylabel('Frozen')
plt.title('region wise frozen ')
plt.show()
plt.subplot(3, 1, 2)
plt.bar(data.Region , data.Detergents_Paper,color='g')
plt.xlabel('Region')
plt.ylabel('Detergents_Paper')
plt.title('region wise Detergents_Paper')
plt.show()
plt.subplot(3, 1, 3)
plt.bar(data.Region , data.Delicassen,color='g')
plt.xlabel('Region')
plt.ylabel('Delicassen')
plt.title('region wise Delicassen')
plt.show()

# %% [markdown]
# # observations from above graph
# 1.the customers from region 3 are spending  more  tahn the region 1 and 2
# 2.other than frozen products customers from region 3 are speding on the other products.these customers are spending less on prerved products

# %% [markdown]
# # channel wise data

# %%
plt.subplot(3, 1, 1)
plt.bar(data.Channel , data.Milk,color='g')
plt.xlabel('Channel')
plt.ylabel('Milk')
plt.title('Channel wise milk')
plt.show()
plt.subplot(3, 1, 2)
plt.bar(data.Channel , data.Fresh,color='g')
plt.xlabel('Channel')
plt.ylabel('Fresh')
plt.title('Channel wise freshness')
plt.show()
plt.subplot(3, 1, 3)
plt.bar(data.Channel , data.Grocery,color='g')
plt.xlabel('Channel')
plt.ylabel('Grocery')
plt.title('Channel wise grocery')
plt.show()

# %%
plt.subplot(3, 1, 1)
plt.bar(data.Channel , data.Frozen,color='g')
plt.xlabel('Channel')
plt.ylabel('Frozen')
plt.title('Channel wise frozen ')
plt.show()
plt.subplot(3, 1, 2)
plt.bar(data.Channel , data.Detergents_Paper,color='g')
plt.xlabel('Channel')
plt.ylabel('Detergents_Paper')
plt.title('Channel wise Detergents_Paper')
plt.show()
plt.subplot(3, 1, 3)
plt.bar(data.Channel , data.Delicassen,color='g')
plt.xlabel('Channel')
plt.ylabel('Delicassen')
plt.title('Channel wise Delicassen')
plt.show()

# %%
def draw_hist(data, X, title):
    sns.distplot(data[X]).set_title(title)
    plt.show()

# %%
# crosstab on Sex and Pclass
pd.crosstab(data.Channel, data.Region)
# Out:
# Region    1   2    3
# Channel
# 1        59  28  211
# 2        18  19  105

# %%
pd.crosstab(data.Channel, data.Region).plot(kind='bar');

# %% [markdown]
# # 2/ Do Feature Scaling

# %%
# Normalising continuous features
df = data[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']]

# %%
normalized_df=(df-df.mean())/df.std()
data1 = data.drop(['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen'], 1)
data1 = pd.concat([data1,normalized_df],axis=1)
data1.head()
# Out:
#    Channel  Region     Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# 0        2       3  0.052873  0.522972 -0.041068 -0.588697         -0.043519
# 1        2       3 -0.390857  0.543839  0.170125 -0.269829          0.086309
# 2        2       3 -0.446521  0.408073 -0.028125 -0.137379          0.133080
# 3        1       3  0.099998 -0.623310 -0.392530  0.686363         -0.498021
# 4        2       3  0.839284 -0.052337 -0.079266  0.173661         -0.231654
#
#    Delicassen
# 0   -0.066264
# 1    0.089050
# 2    2.240742
# 3    0.093305
# 4    1.297870

# %% [markdown]
# #Checking the Churn Rate

# %%
#churn = (sum(data1['Churn'])/len(data1['Churn'].index))*100
#churn

# %% [markdown]
# # 3/ Do Outlier Detection

# %%
# Box plot of milk with region
data[data.Milk.notnull()].boxplot('Milk','Channel');

# %%
# Box plot of fresh with region
data[data.Fresh.notnull()].boxplot('Fresh','Region');

# %%
# Box plot of milk with region
data[data.Grocery.notnull()].boxplot('Grocery','Region');

# %%
# Checking outliers at 25%,50%,75%,90%,95% and 99%
data.describe(percentiles=[.25,.5,.75,.90,.95,.99]).T
# Out:
#                   count          mean           std   min      25%     50%  \
# Channel           440.0      1.322727      0.468052   1.0     1.00     1.0
# Region            440.0      2.543182      0.774272   1.0     2.00     3.0
# Fresh             440.0  12000.297727  12647.328865   3.0  3127.75  8504.0
# Milk              440.0   5796.265909   7380.377175  55.0  1533.00  3627.0
# Grocery           440.0   7951.277273   9503.162829   3.0  2153.00  4755.5
# Frozen            440.0   3071.931818   4854.673333  25.0   742.25  1526.0
# Detergents_Paper  440.0   2881.493182   4767.854448   3.0   256.75   816.5
# Delicassen        440.0   1524.870455   2820.105937   3.0   408.25   965.5
#
#                        75%      90%       95%       99%       max
# Channel               2.00      2.0      2.00      2.00       2.0
# Region                3.00      3.0      3.00      3.00       3.0
# Fresh             16933.75  27090.5  36818.50  56082.61  112151.0
# ...

# %% [markdown]
# From the distribution shown above, you can see that there are outliner in your data

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Channel                 1.00
# Region                  1.00
# Fresh               13806.00
# Milk                 5657.25
# Grocery              8502.75
# Frozen               2812.00
# Detergents_Paper     3665.25
# Delicassen           1412.00
# dtype: float64

# %%
data.shape
# Out:
# (440, 8)

# %%
data2 = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
data2.describe(percentiles=[.25,.5,.75,.90,.95,.99]).T
# Out:
#                   count         mean          std   min      25%     50%  \
# Channel           332.0     1.286145     0.452640   1.0     1.00     1.0
# Region            332.0     2.539157     0.782148   1.0     2.00     3.0
# Fresh             332.0  9547.397590  8161.831206   3.0  2989.75  7483.5
# Milk              332.0  4105.180723  3363.303146  55.0  1352.50  3087.0
# Grocery           332.0  5875.614458  5038.930756   3.0  2011.50  3835.5
# Frozen            332.0  1863.048193  1707.890373  25.0   582.00  1270.5
# Detergents_Paper  332.0  1958.975904  2347.470292   3.0   231.75   715.5
# Delicassen        332.0  1016.602410   824.356784   3.0   360.75   774.0
#
#                        75%      90%       95%       99%      max
# Channel               2.00      2.0      2.00      2.00      2.0
# Region                3.00      3.0      3.00      3.00      3.0
# Fresh             13987.25  20915.5  26462.55  33634.98  37036.0
# ...

# %%
data.Milk.plot(kind='box');

# %%
data_z.Milk.plot(kind='box');

# %%
# Box plot of fresh with region
data2[data2.Milk.notnull()].boxplot('Milk','Region');

# %%
data_z.shape
# Out:
# (332, 8)

# %% [markdown]
# # 4/ Use principal component analysis (PCA) to draw conclusions about the underlying structure of the wholesale customer data

# %%
data2.shape
# Out:
# (332, 8)

# %%
#Improting the PCA module
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized', random_state=42)

# %%
#Doing the PCA on the train data
pca.fit(data2)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=42,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %% [markdown]
# Let's plot the principal components and try to make sense of them

# %%
pca.components_
# Out:
# array([[-1.22882497e-05, -1.10006829e-06,  9.77814724e-01,
#         -8.11750587e-02, -1.57911365e-01,  4.51374682e-02,
#         -1.00691376e-01,  1.32978322e-02],
#        [ 5.48609015e-05,  1.02161091e-05,  2.02021852e-01,
#          4.62348537e-01,  7.97665017e-01, -4.65312699e-02,
#          3.23588747e-01,  4.77145963e-02],
#        [ 1.67095599e-06, -8.13786997e-06,  1.60049665e-02,
#         -8.78048209e-01,  4.58666158e-01, -5.03776991e-02,
#          1.14446699e-01, -5.25792789e-02],
#        [-9.85815608e-06, -4.22273727e-05, -3.54968656e-02,
#         -2.15471009e-02,  7.14587181e-02,  9.95385968e-01,
#          1.30051003e-02,  4.69785689e-02],
#        [-1.03166699e-04, -1.51804013e-05, -3.58325623e-02,
#          5.38447267e-02,  3.46901031e-01, -1.81573731e-02,
#         -9.28789374e-01,  1.11790185e-01],
#        [ 3.43452078e-05,  2.51081759e-05, -1.62904436e-02,
#         -7.28851902e-02, -5.45270885e-02, -4.62235761e-02,
# ...

# %%
colnames = list(data2.columns)
pcs_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1],'PC3':pca.components_[2] ,'Feature':colnames})
pcs_df.head()
# Out:
#         PC1       PC2       PC3  Feature
# 0 -0.000012  0.000055  0.000002  Channel
# 1 -0.000001  0.000010 -0.000008   Region
# 2  0.977815  0.202022  0.016005    Fresh
# 3 -0.081175  0.462349 -0.878048     Milk
# 4 -0.157911  0.797665  0.458666  Grocery

# %%
# %matplotlib inline
fig = plt.figure(figsize = (8,8))
plt.scatter(pcs_df.PC1, pcs_df.PC2)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
for i, txt in enumerate(pcs_df.Feature):
    plt.annotate(txt, (pcs_df.PC1[i],pcs_df.PC2[i]))
plt.tight_layout()
plt.show()

# %%
#cumullative
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.60615302, 0.92273661, 0.96019405, 0.9843317 , 0.99497301,
#        0.99999999, 1.        , 1.        ])

# %%
pca.explained_variance_ratio_
# Out:
# array([6.06153017e-01, 3.16583597e-01, 3.74574331e-02, 2.41376522e-02,
#        1.06413158e-02, 5.02697901e-03, 5.36348500e-09, 6.49436147e-10])

# %%
#Making the screeplot - plotting the cumulative variance against the number of components
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# Looks like 3 components are enough to describe 95% of the variance in the dataset¶
# We'll choose 3 components for our modeling

# %%
#Using incremental PCA for efficiency - saves a lot of time on larger datasets
from sklearn.decomposition import IncrementalPCA
pca_final = IncrementalPCA(n_components=3)

# %%
wholesale_pca = pca_final.fit_transform(data2)
wholesale_pca.shape
# Out:
# (332, 3)

# %% [markdown]
# Creating correlation matrix for the principal components - we expect little to no correlation

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(wholesale_pca.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
# 1s -> 0s in diagonals
corrmat_nodiag = corrmat - np.diagflat(corrmat.diagonal())
print("max corr:",corrmat_nodiag.max(), ", min corr: ", corrmat_nodiag.min(),)
# we see that correlations are indeed very close to 0
# Out:
# max corr: 0.00012744229982734878 , min corr:  -0.0004156232322146345

# %% [markdown]
# # 5/ Do K means clustering

# %%
from sklearn.cluster import KMeans

# %%
data.shape
# Out:
# (440, 8)

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
# Scale the data
from sklearn.preprocessing import scale as scale
scaled_RCDF = scale(data.iloc[:,2:8])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by the scale function.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
## Identify the optimal number of clusters 
# elbow method
cluster_range = range( 1, 10 )
cluster_wss = []

for num_clusters in cluster_range:
    clusters = KMeans( num_clusters )
    clusters.fit(scaled_RCDF)
    cluster_wss.append( clusters.inertia_ )
from collections import OrderedDict
clusters_df = pd.DataFrame( OrderedDict ( 
        {"num_clusters": cluster_range, 
        "cluster_wss": cluster_wss }
        ) )
clusters_df[0:10]
# Out:
#    num_clusters  cluster_wss
# 0             1  2640.000000
# 1             2  1954.183565
# 2             3  1626.831543
# 3             4  1327.174059
# 4             5  1058.771253
# 5             6   915.769881
# 6             7   824.999047
# 7             8   751.584835
# 8             9   659.861256

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Number of Clusters')
plt.ylabel('Within Sum of Squares')
plt.xticks(np.arange(min(clusters_df.num_clusters), 
                     max(clusters_df.num_clusters)+1, 
                     1.0))
plt.plot( clusters_df.num_clusters, 
         clusters_df.cluster_wss, 
         marker = "o" )

# %%
## Profiling the clusters

clusterer = KMeans(n_clusters=2, random_state=10)
cluster_labels = clusterer.fit_predict(scaled_RCDF)
cluster_labels
data['Clusters'] = cluster_labels

clus_profile = data.iloc[:,2:9].groupby(['Clusters'], 
                       as_index=False).mean()
clus_profile
# Out:
#    Clusters         Fresh          Milk       Grocery       Frozen  \
# 0         0  12802.404762  20572.690476  29049.880952  4653.642857
# 1         1  11915.653266   4236.944724   5724.791457  2905.017588
#
#    Detergents_Paper   Delicassen
# 0      13424.214286  4046.404762
# 1       1768.944724  1258.778894

# %%
from sklearn.decomposition import PCA
pca_2 = PCA(2)
plot_columns = pca_2.fit_transform(scaled_RCDF)

## Getting a Visual Plot 
## Defining Colours and Labels for the Plot
def color_fun (row):
   if (row['Clusters'] == 0):
      return "red"
   if (row['Clusters'] == 1):
      return "green"
   if (row['Clusters'] == 2):
      return "blue"
   return 0

data['color'] = data.apply (lambda row: color_fun(row), axis=1)
plot_labels = data['Region'].values.ravel()

# %%
## Show the Cluster Plot
plt.scatter(x=plot_columns[:,0], 
            y=plot_columns[:,1],
            c=data['color'].values.tolist(),
            s=50, edgecolors='none')

for label, x, y in zip(
        plot_labels, plot_columns[:,0], 
        plot_columns[:,1]) :
    plt.annotate(
    label,
    xy=(x, y), xytext=(10, 2),
    textcoords='offset points', ha='right', va='bottom',
    )
    plt.xlabel('PC1')
    plt.ylabel('PC2')

plt.show()

# %% [markdown]
# # 6/ Explain what you have done and how this segments customers

# %% [markdown]
# 1.imported the data
# 2.performed preprocessing steps
# 3.did eda based on the features
#     found out region 3 customers are speding most of their spendings
# 4.from box plots and the iqr found that there are outliers in the data and they are treated by deleted the outliers
# 5.did feature scaling
# 6.perfomed pca
#     3 components have been taken in to consideration for the model building
# 7.performed k_means
#    clustering is done on the basis of region_wise
#
# so , insight  region 3 might be a city or that might be the higher community(rich people)
